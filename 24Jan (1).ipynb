# %%
import pandas as pd
import numpy as np
data=pd.read_csv("clevelanda (1).csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   gender    303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fps       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  class     303 non-null    int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 33.3+ KB

# %%
data.shape
# Out:
# (303, 14)

# %%
data
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0     63       1   1       145   233    1        2      150      0      2.3
# 1     67       1   4       160   286    0        2      108      1      1.5
# 2     67       1   4       120   229    0        2      129      1      2.6
# 3     37       1   3       130   250    0        0      187      0      3.5
# 4     41       0   2       130   204    0        2      172      0      1.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
# 302   38       1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  class
# 0        3  0    6      0
# ...

# %%
for column in data.columns:
    print("Unique values for column",column)
    print(data[column].unique())
# Out:
# Unique values for column age
# [63 67 37 41 56 62 57 53 44 52 48 54 49 64 58 60 50 66 43 40 69 59 42 55
#  61 65 71 51 46 45 39 68 47 34 35 29 70 77 38 74 76]
# Unique values for column gender
# [1 0]
# Unique values for column cp
# [1 4 3 2]
# Unique values for column trestbps
# [145 160 120 130 140 172 150 110 132 117 135 112 105 124 125 142 128 170
#  155 104 180 138 108 134 122 115 118 100 200  94 165 102 152 101 126 174
#  148 178 158 192 129 144 123 136 146 106 156 154 114 164]
# Unique values for column chol
# [233 286 229 250 204 236 268 354 254 203 192 294 256 263 199 168 239 275
#  266 211 283 284 224 206 219 340 226 247 167 230 335 234 177 276 353 243
#  225 302 212 330 175 417 197 198 290 253 172 273 213 305 216 304 188 282
#  185 232 326 231 269 267 248 360 258 308 245 270 208 264 321 274 325 235
#  257 164 141 252 255 201 222 260 182 303 265 309 307 249 186 341 183 407
#  217 288 220 209 227 261 174 281 221 205 240 289 318 298 564 246 322 299
# ...

# %%
data.replace('?', np.NaN)
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0     63       1   1       145   233    1        2      150      0      2.3
# 1     67       1   4       160   286    0        2      108      1      1.5
# 2     67       1   4       120   229    0        2      129      1      2.6
# 3     37       1   3       130   250    0        0      187      0      3.5
# 4     41       0   2       130   204    0        2      172      0      1.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
# 302   38       1   3       138   175    0        0      173      0      0.0
#
#      slope   ca thal  class
# ...

# %%
data["ca"]=pd.to_numeric(data["ca"], errors='coerce')
print(data["ca"])
data["thal"]=pd.to_numeric(data["thal"], errors='coerce')
print(data["thal"])
# Out:
# 0      0.0
# 1      3.0
# 2      2.0
# 3      0.0
# 4      0.0
#       ...
# 298    0.0
# 299    2.0
# 300    1.0
# 301    1.0
# 302    NaN
# Name: ca, Length: 303, dtype: float64
# 0      6.0
# 1      3.0
# 2      7.0
# 3      3.0
# 4      3.0
#       ...
# 298    7.0
# 299    7.0
# 300    7.0
# 301    3.0
# 302    3.0
# Name: thal, Length: 303, dtype: float64

# %%
print(data["ca"].mean())
# Out:
# 0.6722408026755853

# %%
ca_mean=data["ca"].mean()
print(ca_mean)
ca_median=(data["ca"].median())
print(ca_median)
ca_mode=data["ca"].mode()[0]
print(ca_mode)
thal_mean=data["thal"].mean()
print(thal_mean)
thal_median=(data["thal"].median())
print(thal_median)
thal_mode=(data["thal"].mode())[0]
print(thal_mode)
# Out:
# 0.6722408026755853
# 0.0
# 0.0
# 4.73421926910299
# 3.0
# 3.0

# %%
data['ca']=data['ca'].fillna(ca_mode)
data['thal']=data['thal'].fillna(thal_mode)
data.isnull().sum()
# Out:
# age         0
# gender      0
# cp          0
# trestbps    0
# chol        0
# fps         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# class       0
# dtype: int64

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
#univariate analysis

#histogram:shows data distribution
#box plot:highlights summary statistics(mean,median,mode)
#bar chart:displays frequency of categories

#bivariate analysis

#scatter plot:visualizes relation between two continuous variables
#line plot:tracks changes in two related variables over time
#heatmap:shows correlation in matrix format

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5])
y = x*2

# first plot with X and Y data
plt.plot(x, y, marker='o')

plt.xlabel("X-axis data")
plt.ylabel("Y-axis data")
plt.title('Simple plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Jan', 'Feb', 'March', 'April', 'May', 'June'])
y = np.array([10000,10500,9000,8500,12000,11000])

# first plot with X and Y data
plt.plot(x, y, marker='o', linestyle='dashed', color='green')

plt.xlabel("Months")
plt.ylabel("Savings amt")
plt.title('Savings from January to June')
plt.show()

# %%
categories=['A','B','C','D','E']
values=[10,15,7,12,9]
plt.bar(categories,values,color=['violet','indigo','blue','green','yellow'])
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Categories vs Values')
plt.show()

# %%
categories=[22,25,30,35,40,45,50]
values=[10,20,30,40,50]
plt.hist(categories,bins=values,color='violet',edgecolor='black')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Categories vs Values')
plt.show()

# %%
lang=['python','java','c','javascript','c++']
per=[23,30,20,17,10]
plt.pie(per,labels=lang,autopct='%1.1f%%')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Categories vs Values')
plt.legend()
plt.show()
